# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy as tw
apikey = "5Qn9tlr40UfqkgpECkrydAjyY"
apisecretkey = "2hhjJc17GYXhtdc3njMnDMDRXuTlHyHDtnydOAUIPkadhCdmMr"
accesstoken = "1381706746675277824-TxCA0rRhffjNeSC8B33c47hqRYebe1"
accesstokensecret = "wKkdzYrz2nXHaG3QL5W78KlBGmRvRdIYyqY1sHGLYGRJ9"
auth = tw.OAuthHandler(apikey,apisecretkey) 
auth.set_access_token(accesstoken,accesstokensecret) 
api = tw.API(auth,wait_on_rate_limit=True)

# %%
search_word = '#bitcoin'
date_since = '2015-01-01'

# %%
tweets = tw.Cursor(api.search,q = search_word, lang ='en',since = date_since).items(5000)

# %%
tweet_details = [[tweet.geo,tweet.text,tweet.user.verified,tweet.created_at]for tweet in tweets]

# %%
tweet_details
# Out:
# [[None,
#   'RT @Sweepsgg: I’m giving $100 to one lucky follower that retweets this within the next 24 hours. #Bitcoin\xa0 \n\nTo enter:\n- Follow @CryptoPoor…',
#   False,
#   datetime.datetime(2021, 4, 15, 8, 26, 37)],
#  [None,
#   'RT @DocumentingBTC: Coinbase is now worth more than Goldman Sachs, who called #bitcoin "not an asset class" last year.',
#   False,
#   datetime.datetime(2021, 4, 15, 8, 26, 35)],
#  [None,
#   'RT @Sweepsgg: I’m giving $100 to one lucky follower that retweets this within the next 24 hours. #Bitcoin\xa0 \n\nTo enter:\n- Follow @CryptoPoor…',
#   False,
#   datetime.datetime(2021, 4, 15, 8, 26, 35)],
#  [None,
#   'RT @fiduzzi: I hate when people are saying they will buy #Bitcoin when it gets cheaper.\n\nPrice is what you pay. Value is what you get.',
#   False,
#   datetime.datetime(2021, 4, 15, 8, 26, 35)],
#  [None,
# ...

# %%
import pandas as pd 
columns = ['Geo Location','Tweet Text','Verified','Date']
tweets_df = pd.DataFrame(tweet_details,columns=columns)

# %%
tweets_df
# Out:
#      Geo Location                                         Tweet Text  \
# 0            None  RT @Sweepsgg: I’m giving $100 to one lucky fol...
# 1            None  RT @DocumentingBTC: Coinbase is now worth more...
# 2            None  RT @Sweepsgg: I’m giving $100 to one lucky fol...
# 3            None  RT @fiduzzi: I hate when people are saying the...
# 4            None  RT @ETHERU12: Thank you very much for your fee...
# ...           ...                                                ...
# 4995         None  RT @ENewsMan: There aren't many things that ex...
# 4996         None  RT @CryptoPoorBoy: I will give $1,000 to 10 Ra...
# 4997         None  RT @Sweepsgg: I’m giving $100 to one lucky fol...
# 4998         None  RT @IIICapital: #Bitcoin is 1 black swan event...
# 4999         None  RT @flurbnb: 🔥 $100 to someone who retweets th...
#
#       Verified                Date
# 0        False 2021-04-15 08:26:37
# 1        False 2021-04-15 08:26:35
# ...

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Geo Location  0 non-null      object
#  1   Tweet Text    5000 non-null   object
#  2   Verified      5000 non-null   bool
#  3   Date          5000 non-null   datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), object(2)
# memory usage: 122.2+ KB

# %%
tweets_df.to_csv('Twitter Data2')

# %%
# Getting the second batch of data 
# !pip install GetOldTweets3

# %%
import GetOldTweets3 as got
keyword = "#bitcoin"
oldest_date = "2012-01-01"    
newest_date = "2012-12-12"
number_tweets = 1000

# %%
tweet_criteria = got.manager.TweetCriteria().setQuerySearch(keyword)\
                                            .setSince(oldest_date)\
                                            .setUntil(newest_date)\
                                            .setMaxTweets(number_tweets)
tweet_criteria
#tweet_df = pd.DataFrame({'got_criteria':got.manager.TweetManager.getTweets(tweet_criteria)})

# %%
import sys
if sys.version_info[0] < 3:
    import got

def main():


    def printTweet(descr, t):
        print(descr)
        print("Username: %s" % t.username)
        print("Retweets: %d" % t.retweets)
        print("Text: %s" % t.text)
        print("Mentions: %s" % t.mentions)
        print("Hashtags: %s\n" % t.hashtags)

# %%
# Example 1 - Get tweets by username
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#Bitcoin').setMaxTweets(5000)
tweetCriteria
#tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]

# %%
	# Example 2 - Get tweets by query search
	tweetCriteria = got.manager.TweetCriteria().setQuerySearch('europe refugees').setSince("2015-05-01").setUntil("2015-09-30").setMaxTweets(1)
	tweet = got.manager.TweetMa
    
nager.getTweets(tweetCriteria)[0]

# %%
#set search variables
keyword = "#Bitcoin"
oldest_date = "2012-12-12"    
newest_date = "2012-01-01"
locations = ["Africa", "Europe", "America", "Australia", "Asia"]
number_tweets = 2000

# %%
#get old tweets
tweetCriteria_list = []
for location in locations:
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch(keyword)\
                                           .setSince(oldest_date)\
                                           .setUntil(newest_date)\
                                            .setNear(location)\
                                           .setMaxTweets(number_tweets)
    tweetCriteria_list.append(tweetCriteria)

# %%
tweetCriteria.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-5ba64709040c> in <module>
# ----> 1 tweetCriteria.count()
#
# AttributeError: 'TweetCriteria' object has no attribute 'count'

# %%
#create twitter info for each city
tweet_dict = {}
for criteria, location in zip(tweetCriteria_list, locations):
    tweets = got.manager.TweetManager.getTweets(criteria)
    tweet_dict[location] = tweets
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# An error occured during an HTTP request: HTTP Error 404: Not Found
# Try to open in browser: https://twitter.com/search?q=%23Bitcoin%20near%3A%22Africa%22%20within%3A15mi%20since%3A2012-12-12%20until%3A2012-01-01&src=typd
# Traceback (most recent call last):
#   File "C:\Users\mutho\anaconda3\lib\site-packages\GetOldTweets3\manager\TweetManager.py", line 343, in getJsonResponse
#     response = opener.open(url)
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
# ...

# %%
tweetCriteria = got.manager.TweetCriteria().setUsername('Coin Desk').setMaxTweets(15)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# An error occured during an HTTP request: HTTP Error 404: Not Found
# Try to open in browser: https://twitter.com/search?q=%20from%3Acoin%20desk&src=typd
# Traceback (most recent call last):
#   File "C:\Users\mutho\anaconda3\lib\site-packages\GetOldTweets3\manager\TweetManager.py", line 343, in getJsonResponse
#     response = opener.open(url)
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\mutho\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
# ...
